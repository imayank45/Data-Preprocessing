# %% [markdown]
# ## Removing Null Value Rows

# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\Mayank\Downloads\googleplaystore.csv')

# %%
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df.isnull()
# Out:
#          App  Category  Rating  Reviews   Size  Installs   Type  Price  \
# 0      False     False   False    False  False     False  False  False
# 1      False     False   False    False  False     False  False  False
# 2      False     False   False    False  False     False  False  False
# 3      False     False   False    False  False     False  False  False
# 4      False     False   False    False  False     False  False  False
# ...      ...       ...     ...      ...    ...       ...    ...    ...
# 10836  False     False   False    False  False     False  False  False
# 10837  False     False   False    False  False     False  False  False
# 10838  False     False    True    False  False     False  False  False
# 10839  False     False   False    False  False     False  False  False
# 10840  False     False   False    False  False     False  False  False
#
#        Content Rating  Genres  Last Updated  Current Ver  Android Ver
# ...

# %%
df.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %%
data = df.dropna()

# %%
data.isnull().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              0
# Price             0
# Content Rating    0
# Genres            0
# Last Updated      0
# Current Ver       0
# Android Ver       0
# dtype: int64

# %%
data
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10834                                      FR Calculator               FAMILY
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %% [markdown]
# ## Data Analysis - Numeric

# %% [markdown]
# Finding Average Rating

# %%
data
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10834                                      FR Calculator               FAMILY
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
data['Rating']
# Out:
# 0        4.1
# 1        3.9
# 2        4.7
# 3        4.5
# 4        4.3
#         ...
# 10834    4.0
# 10836    4.5
# 10837    5.0
# 10839    4.5
# 10840    4.5
# Name: Rating, Length: 9360, dtype: float64

# %%
c = 0
for i in data['Rating']:
    c += i
c/9360
# Out:
# 4.191837606837612

# %%
float(str(sum(data['Rating'])/len(data['Rating']))[:4])
# Out:
# 4.19

# %% [markdown]
# Find number of applications with rating 5?

# %%
c = 0
for i in data['Rating']:
    if i == 5.0:
        c+=1
print('Number of apps with rating 5 are',c,)
# Out:
# Number of apps with rating 5 are 274

# %% [markdown]
# Find number of application with rating 4-4.5?

# %%
c = 0
for i in data['Rating']:
    if i >= 4.0 and i <= 4.5:
        c += 1
print('Number of apps with rating 4-4.5 are',c,)
# Out:
# Number of apps with rating 4-4.5 are 5446

# %% [markdown]
# ## Data Analysis - Categorical

# %%
data
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10834                                      FR Calculator               FAMILY
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %% [markdown]
# Find number of categories?

# %%
for i in data['Category'].unique():
    print(i)
# Out:
# ART_AND_DESIGN
# AUTO_AND_VEHICLES
# BEAUTY
# BOOKS_AND_REFERENCE
# BUSINESS
# COMICS
# COMMUNICATION
# DATING
# EDUCATION
# ENTERTAINMENT
# EVENTS
# FINANCE
# FOOD_AND_DRINK
# HEALTH_AND_FITNESS
# HOUSE_AND_HOME
# LIBRARIES_AND_DEMO
# LIFESTYLE
# GAME
# FAMILY
# MEDICAL
# SOCIAL
# SHOPPING
# PHOTOGRAPHY
# SPORTS
# TRAVEL_AND_LOCAL
# TOOLS
# PERSONALIZATION
# PRODUCTIVITY
# PARENTING
# WEATHER
# VIDEO_PLAYERS
# NEWS_AND_MAGAZINES
# MAPS_AND_NAVIGATION

# %%
p = len(data['Category'].unique())
print('There are total',p,'categories.')
# Out:
# There are total 33 categories.

# %% [markdown]
# Find total number of apps comes in category of ART_AND_DESIGN?

# %%
c = 0
for i in data['Category']:
    if i == 'ART_AND_DESIGN':
        c += 1
print('There are',c,'apps comes in category of ART_AND_DESIGN.')
# Out:
# There are 61 apps comes in category of ART_AND_DESIGN.

# %% [markdown]
# Find total number apps types?

# %%
data['Type'].unique()
# Out:
# array(['Free', 'Paid'], dtype=object)

# %% [markdown]
# Find total number of free and paid apps?

# %%
f = 0
for i in data['Type']:
    if i == 'Free':
        f += 1

p = 0        
for i in data['Type']:
    if i == 'Paid':
        p += 1
        
print('There are total',f,'free and',p,'paid applications.')
# Out:
# There are total 8715 free and 645 paid applications.

# %% [markdown]
# Find percentage of free apps in dataset?

# %%
print(int(f/(f+p)*100),'% of applications are free.')
# Out:
# 93 % of applications are free.

# %% [markdown]
# Name all content rating?

# %%
for i in data['Content Rating'].unique():
    print(i)
# Out:
# Everyone
# Teen
# Everyone 10+
# Mature 17+
# Adults only 18+
# Unrated

# %% [markdown]
# Find total number of apps in each category?

# %%
for name in data['Category'].unique():
    ct = 0
    for i in data['Category']:
        if i == name:
            ct += 1
    print(name,':',ct)
# Out:
# ART_AND_DESIGN : 61
# AUTO_AND_VEHICLES : 73
# BEAUTY : 42
# BOOKS_AND_REFERENCE : 178
# BUSINESS : 303
# COMICS : 58
# COMMUNICATION : 328
# DATING : 195
# EDUCATION : 155
# ENTERTAINMENT : 149
# EVENTS : 45
# FINANCE : 323
# FOOD_AND_DRINK : 109
# HEALTH_AND_FITNESS : 297
# HOUSE_AND_HOME : 76
# LIBRARIES_AND_DEMO : 64
# LIFESTYLE : 314
# GAME : 1097
# FAMILY : 1746
# MEDICAL : 350
# SOCIAL : 259
# SHOPPING : 238
# PHOTOGRAPHY : 317
# SPORTS : 319
# TRAVEL_AND_LOCAL : 226
# TOOLS : 733
# PERSONALIZATION : 312
# PRODUCTIVITY : 351
# PARENTING : 50
# WEATHER : 75
# VIDEO_PLAYERS : 160
# NEWS_AND_MAGAZINES : 233
# MAPS_AND_NAVIGATION : 124

# %%
categories = {}
for name in data['Category'].unique():
    ct = 0
    for i in data['Category']:
        if i == name:
            ct += 1
    categories[name] = ct
categories
# Out:
# {'ART_AND_DESIGN': 61,
#  'AUTO_AND_VEHICLES': 73,
#  'BEAUTY': 42,
#  'BOOKS_AND_REFERENCE': 178,
#  'BUSINESS': 303,
#  'COMICS': 58,
#  'COMMUNICATION': 328,
#  'DATING': 195,
#  'EDUCATION': 155,
#  'ENTERTAINMENT': 149,
#  'EVENTS': 45,
#  'FINANCE': 323,
#  'FOOD_AND_DRINK': 109,
#  'HEALTH_AND_FITNESS': 297,
#  'HOUSE_AND_HOME': 76,
#  'LIBRARIES_AND_DEMO': 64,
#  'LIFESTYLE': 314,
#  'GAME': 1097,
#  'FAMILY': 1746,
#  'MEDICAL': 350,
#  'SOCIAL': 259,
#  'SHOPPING': 238,
#  'PHOTOGRAPHY': 317,
#  'SPORTS': 319,
#  'TRAVEL_AND_LOCAL': 226,
#  'TOOLS': 733,
#  'PERSONALIZATION': 312,
#  'PRODUCTIVITY': 351,
#  'PARENTING': 50,
#  'WEATHER': 75,
#  'VIDEO_PLAYERS': 160,
#  'NEWS_AND_MAGAZINES': 233,
#  'MAPS_AND_NAVIGATION': 124}

# %% [markdown]
# Find total number of apps in each type?

# %%
types = {}
for name in data['Type'].unique():
    ct = 0
    for i in data['Type']:
        if i == name:
            ct += 1
    types[name] = ct
types
# Out:
# {'Free': 8715, 'Paid': 645}

# %% [markdown]
# Find total number of apps in each content_rating?

# %%
data
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10834                                      FR Calculator               FAMILY
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
content_rating = {}
for name in data['Content Rating'].unique():
    ct = 0
    for i in data['Content Rating']:
        if i == name:
            ct += 1
    content_rating[name] = ct
content_rating
# Out:
# {'Everyone': 7414,
#  'Teen': 1084,
#  'Everyone 10+': 397,
#  'Mature 17+': 461,
#  'Adults only 18+': 3,
#  'Unrated': 1}

# %%
data['Rating'].describe()
# Out:
# count    9360.000000
# mean        4.191838
# std         0.515263
# min         1.000000
# 25%         4.000000
# 50%         4.300000
# 75%         4.500000
# max         5.000000
# Name: Rating, dtype: float64

# %% [markdown]
# ## Null Values Hanndling - Numeric

# %%
df = pd.read_csv(r'C:\Users\Mayank\Downloads\data.csv')

# %%
df
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0       Yes
# 1    Spain  27.0  48000.0       Yes
# 2      NaN  30.0  54000.0       NaN
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0      NaN       Yes
# 5   France  35.0  58000.0       Yes
# 6    Spain   NaN  52000.0        No
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %% [markdown]
# ### 1] Removing the rows.

# %%
df.isnull().sum()
# Out:
# Country      1
# Age          1
# Salary       1
# Purchased    1
# dtype: int64

# %%
df.dropna()
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0       Yes
# 1    Spain  27.0  48000.0       Yes
# 3    Spain  38.0  61000.0        No
# 5   France  35.0  58000.0       Yes
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %% [markdown]
# ### 2] Imputers

# %%
import numpy as np
from sklearn.impute import SimpleImputer
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\Mayank\Downloads\data.csv')

# %%
df
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0       Yes
# 1    Spain  27.0  48000.0       Yes
# 2      NaN  30.0  54000.0       NaN
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0      NaN       Yes
# 5   France  35.0  58000.0       Yes
# 6    Spain   NaN  52000.0        No
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %%
imputer = SimpleImputer(missing_values = np.nan, strategy = 'most_frequent')

# %%
imputer.fit(df.iloc[:,:].values)
# Out:
# SimpleImputer(strategy='most_frequent')

# %%
df.iloc[:,:] = imputer.transform(df.iloc[:,:].values)

# %%
df
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0       Yes
# 1    Spain  27.0  48000.0       Yes
# 2   France  30.0  54000.0       Yes
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0  48000.0       Yes
# 5   France  35.0  58000.0       Yes
# 6    Spain  27.0  52000.0        No
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %% [markdown]
# ## Null Values Handling on GooglePlaystore dataset

# %%
df = pd.read_csv(r'C:\Users\Mayank\Downloads\googleplaystore.csv')

# %%
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %%
from sklearn.impute import SimpleImputer

# %%
imputer = SimpleImputer(missing_values = np.nan, strategy = 'mean')

# %%
imputer.fit(df.iloc[:,2:3].values)
# Out:
# SimpleImputer()

# %%
df.iloc[:,2:3] = imputer.transform(df.iloc[:,2:3].values)

# %%
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df.isnull().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              1
# Price             0
# Content Rating    1
# Genres            0
# Last Updated      0
# Current Ver       8
# Android Ver       3
# dtype: int64

# %%
df = df.dropna()

# %%
df.isnull().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              0
# Price             0
# Content Rating    0
# Genres            0
# Last Updated      0
# Current Ver       0
# Android Ver       0
# dtype: int64
